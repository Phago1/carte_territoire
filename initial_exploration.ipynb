# %% [markdown]
# # Initial Exploration

# %% [markdown]
# ### Load data

# %%
pip install pandas
# Out:
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install Geopandas
# Out:
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install rasterio
# Out:
# ...
#   Using cached attrs-25.4.0-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# ...
#   Using cached pyparsing-3.2.5-py3-none-any.whl.metadata (5.0 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.3/22.3 MB 12.1 MB/s eta 0:00:00a 0:00:01
# ...
# Using cached attrs-25.4.0-py3-none-any.whl (67 kB)
# ...
# Using cached pyparsing-3.2.5-py3-none-any.whl (113 kB)
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd

# %%
tile_name = '90-2023-0980-6730-LA93-0M20-IRC-E080_res1.00m'
im = Image.open(f'raw_data/{tile_name}.tif')
im_label = Image.open(f'raw_data/{tile_name}_labels.tif')
imarray = np.array(im)
imarray_label = np.array(im_label)
df = pd.DataFrame(imarray_label.reshape(5000*5000), columns=['label'])
df.label.value_counts(normalize=True)
# Out:
# label
# 0     0.982240
# 9     0.012332
# 13    0.003887
# 8     0.000922
# 12    0.000420
# 2     0.000121
# 10    0.000079
# Name: proportion, dtype: float64

# %%
import rasterio
import rasterio.features
import rasterio.warp

with rasterio.open('raw_data/90-2023-0980-6730-LA93-0M20-IRC-E080_res1.00m.tif') as dataset:

    # Read the dataset's valid data mask as a ndarray.
    mask = dataset.dataset_mask()

    # Extract feature shapes and values from the array.
    for geom, val in rasterio.features.shapes(
            mask, transform=dataset.transform):

        # Transform shapes from the dataset's own coordinate
        # reference system to CRS84 (EPSG:4326).
        geom = rasterio.warp.transform_geom(
            dataset.crs, 'EPSG:4326', geom, precision=6)

        # Print GeoJSON shapes to stdout.
        print(geom)
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# File rasterio/_base.pyx:310, in rasterio._base.DatasetBase.__init__()
#
# File rasterio/_base.pyx:221, in rasterio._base.open_dataset()
#
# File rasterio/_err.pyx:359, in rasterio._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: example.tif: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# RasterioIOError                           Traceback (most recent call last)
# Cell In[10], line 5
#       2 import rasterio.features
#       3 import rasterio.warp
# ----> 5 with rasterio.open('example.tif') as dataset:
#       6
#       7     # Read the dataset's valid data mask as a ndarray.
#       8     mask = dataset.dataset_mask()
#      10     # Extract feature shapes and values from the array.
#
# ...

# %% [markdown]
# ### Preprocess Data

# %% [markdown]
# ### Instantiate Model
